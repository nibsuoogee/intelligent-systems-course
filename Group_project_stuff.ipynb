# %%
import pandas as pd

original_csv_path = 'C:/Users/Elias/Documents/DEV/ML-data/news_cleaned_2018_02_13.csv'
output_csv_path = 'C:/Users/Elias/Documents/DEV/ML-data/newfile.csv'

df = pd.read_csv(original_csv_path, nrows=50)
df_output = pd.read_csv(output_csv_path, nrows=50)

display(df.head())
display(df_output.head())
# Out:
#    Unnamed: 0  id              domain   type  \
# 0           0   2       express.co.uk  rumor
# 1           1   6  barenakedislam.com   hate
# 2           2   7  barenakedislam.com   hate
# 3           3   8  barenakedislam.com   hate
# 4           4   9  barenakedislam.com   hate
#
#                                                  url  \
# 0  https://www.express.co.uk/news/science/738402/...
# 1  http://barenakedislam.com/category/donald-trum...
# 2  http://barenakedislam.com/category/donald-trum...
# 3  http://barenakedislam.com/2017/12/24/more-winn...
# 4  http://barenakedislam.com/2017/12/25/oh-trump-...
#
#                                              content  \
# 0  Life is an illusion, at least on a quantum lev...
# 1  Unfortunately, he hasn’t yet attacked her for ...
# 2  The Los Angeles Police Department has been den...
# 3  The White House has decided to quietly withdra...
# 4  “The time has come to cut off the tongues of t...
#
# ...

# %%
# imports
import pandas as pd
from sklearn.model_selection import train_test_split
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.sentiment import SentimentIntensityAnalyzer
#nltk.download('wordnet')
#nltk.download('stopwords')
#nltk.download('punkt')
from nltk.corpus import stopwords


# to suppress: "SettingWithCopyWarning"
#pd.options.mode.copy_on_write = True

# %%
#news_path = "./data/fake-news/test.csv"
news_path = "./data/fake-news/news_10_percent_utf8.csv"

df_news = pd.read_csv(news_path)
display(df_news.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4500\3170489430.py in <module>
#       2 news_path = "./data/fake-news/news_10_percent_utf8.csv"
#       3
# ----> 4 df_news = pd.read_csv(news_path)
#       5 display(df_news.head())
#
# ~\miniconda3\envs\py37env\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# Use subset of data for debug
#df_news_10k = df_news.head(10_000)
#df_news_100 = df_news.head(100)

# Select relevant colums
df_trimmed = df_news[["id", "type", "content"]]
display(df_trimmed.head())
# Out:
#    id   type                                            content
# 0   2  rumor  Life is an illusion, at least on a quantum lev...
# 1   6   hate  Unfortunately, he hasn’t yet attacked her for ...
# 2   7   hate  The Los Angeles Police Department has been den...
# 3   8   hate  The White House has decided to quietly withdra...
# 4   9   hate  “The time has come to cut off the tongues of t...

# %%
import swifter
swifter.set_defaults(force_parallel=True)

import spacy

nlp = spacy.load("en_core_web_sm")

df_trimmed['tokenized_content'] = df_trimmed['content'].swifter.apply(lambda x: nlp.tokenizer(x))
# Out:
# Dask Apply:   0%|          | 0/8 [00:00<?, ?it/s]
# C:\Users\Elias\miniconda3\envs\py37env\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
